# %% [markdown]
# ## 꽃 이미지 분류 및 예측 (CNN)

# %%
# flower_photo 디렉토리 밑에 daisy, dandelion, roses, sunflowers, tulips 디렉토리 존재, 약 3670개 사진
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras import layers
import os
import pathlib
import urllib.request
import tarfile

# 데이터 다운로드 함수
def download_and_extract_data():
    # 데이터 URL
    dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

    # 다운로드할 디렉토리 생성
    download_dir = os.path.join(os.getcwd(), 'flower_dataset')
    os.makedirs(download_dir, exist_ok=True)

    # 파일 다운로드
    tgz_path = os.path.join(download_dir, "flower_photos.tgz")

    if not os.path.exists(tgz_path):
        print("데이터셋 다운로드 중...")
        urllib.request.urlretrieve(dataset_url, tgz_path)
        print("다운로드 완료!")

    # 압축 해제
    if not os.path.exists(os.path.join(download_dir, "flower_photos")):
        print("압축 해제 중...")
        with tarfile.open(tgz_path) as tar:
            tar.extractall(path=download_dir)
        print("압축 해제 완료!")

    return os.path.join(download_dir, "flower_photos")

# 데이터 다운로드 및 경로 설정
data_dir = download_and_extract_data()
data_dir = pathlib.Path(data_dir)

# 클래스 및 이미지 개수 확인
classes = sorted([item.name for item in data_dir.glob('*/') if item.is_dir()])
image_count = len(list(data_dir.glob('*/*.jpg')))
print(f"발견된 클래스: {classes}")
print(f"총 이미지 개수: {image_count}")

# 각 클래스별 이미지 개수 확인
for class_name in classes:
    class_images = len(list(data_dir.glob(f'{class_name}/*')))
    print(f"{class_name}: {class_images}개 이미지")
    
# 이미지 크기 및 배치 크기 설정
img_height = 180
img_width = 180
batch_size = 32

# 훈련 데이터셋 생성
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    str(data_dir),
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# 검증 데이터셋 생성
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    str(data_dir),
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# 클래스 이름 확인
class_names = train_ds.class_names
print("클래스:", class_names)
num_classes = len(class_names)

# 데이터셋 성능 최적화
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# 데이터 증강 레이어 정의
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# 샘플 이미지 시각화
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()
# Out:
# 데이터셋 다운로드 중...
# 다운로드 완료!
# 압축 해제 중...
# 압축 해제 완료!
# 발견된 클래스: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# 총 이미지 개수: 3670
# daisy: 633개 이미지
# dandelion: 898개 이미지
# roses: 641개 이미지
# sunflowers: 699개 이미지
# tulips: 799개 이미지
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# 클래스: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
# CNN 모델 구성
model = tf.keras.Sequential([
    data_augmentation,
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# 모델 컴파일
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),  # 다중클래스에서 주로 사용, 각 클래스별 확률 예측 및 손실계산
    metrics=['accuracy']
)

# 모델 구조 출력
model.summary()
# Out:
# c:\Python310\lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Early Stopping 콜백 설정
# 성능이 안좋아질 때 학습을 멈추도록 만듦
"""
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=3,
        restore_best_weights=True
    )
]
"""
# 모델 학습
epochs = 100
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    #callbacks=callbacks
)

# 학습 결과 시각화
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.7757 - loss: 0.6035 - val_accuracy: 0.7371 - val_loss: 0.6587
# Epoch 2/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.7509 - loss: 0.6118 - val_accuracy: 0.6962 - val_loss: 0.7530
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.7753 - loss: 0.5811 - val_accuracy: 0.7139 - val_loss: 0.7078
# Epoch 4/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.7771 - loss: 0.5606 - val_accuracy: 0.7248 - val_loss: 0.6998
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.7894 - loss: 0.5519 - val_accuracy: 0.7221 - val_loss: 0.6617
# Epoch 6/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.7987 - loss: 0.5387 - val_accuracy: 0.7030 - val_loss: 0.8007
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8056 - loss: 0.5151 - val_accuracy: 0.7384 - val_loss: 0.6929
# Epoch 8/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 217ms/step - accuracy: 0.8016 - loss: 0.5276 - val_accuracy: 0.7330 - val_loss: 0.6848
# Epoch 9/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - accuracy: 0.8081 - loss: 0.5083 - val_accuracy: 0.7289 - val_loss: 0.7272
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.8021 - loss: 0.5289 - val_accuracy: 0.7275 - val_loss: 0.6868
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.8193 - loss: 0.4688 - val_accuracy: 0.7207 - val_loss: 0.7252
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.8149 - loss: 0.4755 - val_accuracy: 0.7480 - val_loss: 0.6571
# Epoch 13/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.8089 - loss: 0.4919 - val_accuracy: 0.7575 - val_loss: 0.6506
# Epoch 14/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.8247 - loss: 0.4611 - val_accuracy: 0.7357 - val_loss: 0.7273
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 217ms/step - accuracy: 0.8173 - loss: 0.4696 - val_accuracy: 0.7452 - val_loss: 0.6770
# Epoch 16/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.8186 - loss: 0.4713 - val_accuracy: 0.7248 - val_loss: 0.7348
# Epoch 17/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 209ms/step - accuracy: 0.8454 - loss: 0.4219 - val_accuracy: 0.7411 - val_loss: 0.7273
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.8262 - loss: 0.4730 - val_accuracy: 0.7561 - val_loss: 0.6940
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8318 - loss: 0.4475 - val_accuracy: 0.7616 - val_loss: 0.7327
# Epoch 20/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 209ms/step - accuracy: 0.8398 - loss: 0.4177 - val_accuracy: 0.7330 - val_loss: 0.7937
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8502 - loss: 0.4018 - val_accuracy: 0.7439 - val_loss: 0.6685
# Epoch 22/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8357 - loss: 0.4026 - val_accuracy: 0.7602 - val_loss: 0.6956
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8690 - loss: 0.3725 - val_accuracy: 0.7480 - val_loss: 0.6804
# Epoch 24/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8459 - loss: 0.4189 - val_accuracy: 0.7452 - val_loss: 0.7733
# Epoch 25/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8529 - loss: 0.3767 - val_accuracy: 0.7507 - val_loss: 0.6757
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8518 - loss: 0.3812 - val_accuracy: 0.7411 - val_loss: 0.7554
# Epoch 27/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8445 - loss: 0.4047 - val_accuracy: 0.7384 - val_loss: 0.7913
# Epoch 28/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.8763 - loss: 0.3423 - val_accuracy: 0.7534 - val_loss: 0.7319
# Epoch 29/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8638 - loss: 0.3457 - val_accuracy: 0.7507 - val_loss: 0.7127
# Epoch 30/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.8719 - loss: 0.3360 - val_accuracy: 0.7411 - val_loss: 0.7612
# Epoch 31/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - accuracy: 0.8688 - loss: 0.3503 - val_accuracy: 0.7520 - val_loss: 0.7494
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8636 - loss: 0.3638 - val_accuracy: 0.7520 - val_loss: 0.8246
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8863 - loss: 0.3026 - val_accuracy: 0.7425 - val_loss: 0.7974
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8891 - loss: 0.3037 - val_accuracy: 0.7657 - val_loss: 0.7452
# Epoch 35/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8823 - loss: 0.3183 - val_accuracy: 0.7466 - val_loss: 0.7949
# Epoch 36/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.8858 - loss: 0.3000 - val_accuracy: 0.7221 - val_loss: 0.8142
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8728 - loss: 0.3321 - val_accuracy: 0.7548 - val_loss: 0.8074
# Epoch 38/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8760 - loss: 0.3408 - val_accuracy: 0.7384 - val_loss: 0.8869
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8759 - loss: 0.3247 - val_accuracy: 0.7643 - val_loss: 0.8065
# Epoch 40/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.8986 - loss: 0.2813 - val_accuracy: 0.7589 - val_loss: 0.8211
# Epoch 41/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.8999 - loss: 0.2775 - val_accuracy: 0.7534 - val_loss: 0.8171
# Epoch 42/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9078 - loss: 0.2590 - val_accuracy: 0.7520 - val_loss: 0.7821
# Epoch 43/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9071 - loss: 0.2687 - val_accuracy: 0.7425 - val_loss: 0.8774
# Epoch 44/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.9095 - loss: 0.2802 - val_accuracy: 0.7698 - val_loss: 0.8871
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.9149 - loss: 0.2398 - val_accuracy: 0.7548 - val_loss: 0.8602
# Epoch 46/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.9086 - loss: 0.2545 - val_accuracy: 0.7575 - val_loss: 0.8158
# Epoch 47/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8824 - loss: 0.3201 - val_accuracy: 0.7480 - val_loss: 0.8364
# Epoch 48/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.8957 - loss: 0.2640 - val_accuracy: 0.7657 - val_loss: 0.8114
# Epoch 49/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.9129 - loss: 0.2433 - val_accuracy: 0.7657 - val_loss: 0.8277
# Epoch 50/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - accuracy: 0.8897 - loss: 0.2833 - val_accuracy: 0.7711 - val_loss: 0.8276
# Epoch 51/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.9253 - loss: 0.2217 - val_accuracy: 0.7507 - val_loss: 0.8551
# Epoch 52/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9218 - loss: 0.2347 - val_accuracy: 0.7534 - val_loss: 0.9107
# Epoch 53/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - accuracy: 0.9115 - loss: 0.2326 - val_accuracy: 0.7357 - val_loss: 1.0149
# Epoch 54/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9104 - loss: 0.2494 - val_accuracy: 0.7643 - val_loss: 0.8985
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.9114 - loss: 0.2370 - val_accuracy: 0.7616 - val_loss: 0.8979
# Epoch 56/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 209ms/step - accuracy: 0.9079 - loss: 0.2364 - val_accuracy: 0.7616 - val_loss: 0.8365
# Epoch 57/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 210ms/step - accuracy: 0.9137 - loss: 0.2407 - val_accuracy: 0.7657 - val_loss: 0.9097
# Epoch 58/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.9178 - loss: 0.2314 - val_accuracy: 0.7425 - val_loss: 0.8941
# Epoch 59/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 226ms/step - accuracy: 0.9239 - loss: 0.1997 - val_accuracy: 0.7493 - val_loss: 0.8196
# Epoch 60/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.9162 - loss: 0.2325 - val_accuracy: 0.7493 - val_loss: 0.9629
# Epoch 61/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - accuracy: 0.9164 - loss: 0.2171 - val_accuracy: 0.7411 - val_loss: 1.0117
# Epoch 62/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.9294 - loss: 0.1993 - val_accuracy: 0.7548 - val_loss: 0.9281
# Epoch 63/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - accuracy: 0.9181 - loss: 0.2135 - val_accuracy: 0.7493 - val_loss: 0.9478
# Epoch 64/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.9194 - loss: 0.2262 - val_accuracy: 0.7507 - val_loss: 0.9431
# Epoch 65/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - accuracy: 0.9269 - loss: 0.2126 - val_accuracy: 0.7507 - val_loss: 0.8960
# Epoch 66/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.9169 - loss: 0.2332 - val_accuracy: 0.7670 - val_loss: 1.0131
# Epoch 67/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - accuracy: 0.9315 - loss: 0.1853 - val_accuracy: 0.7507 - val_loss: 1.0174
# Epoch 68/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9327 - loss: 0.1793 - val_accuracy: 0.7711 - val_loss: 0.8920
# Epoch 69/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9358 - loss: 0.1827 - val_accuracy: 0.7616 - val_loss: 1.0267
# Epoch 70/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.9301 - loss: 0.1862 - val_accuracy: 0.7561 - val_loss: 1.1338
# Epoch 71/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.9331 - loss: 0.2035 - val_accuracy: 0.7589 - val_loss: 0.9505
# Epoch 72/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 217ms/step - accuracy: 0.9254 - loss: 0.2016 - val_accuracy: 0.7371 - val_loss: 1.0094
# Epoch 73/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.9303 - loss: 0.1861 - val_accuracy: 0.7561 - val_loss: 0.9864
# Epoch 74/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - accuracy: 0.9439 - loss: 0.1624 - val_accuracy: 0.7575 - val_loss: 1.0097
# Epoch 75/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 224ms/step - accuracy: 0.9460 - loss: 0.1515 - val_accuracy: 0.7602 - val_loss: 1.0657
# Epoch 76/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.9436 - loss: 0.1541 - val_accuracy: 0.7439 - val_loss: 1.1221
# Epoch 77/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.9409 - loss: 0.1702 - val_accuracy: 0.7602 - val_loss: 1.0552
# Epoch 78/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 223ms/step - accuracy: 0.9406 - loss: 0.1645 - val_accuracy: 0.7779 - val_loss: 0.9963
# Epoch 79/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9301 - loss: 0.2022 - val_accuracy: 0.7289 - val_loss: 1.1329
# Epoch 80/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.9405 - loss: 0.1755 - val_accuracy: 0.7616 - val_loss: 1.0236
# Epoch 81/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9394 - loss: 0.1790 - val_accuracy: 0.7629 - val_loss: 1.0007
# Epoch 82/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9536 - loss: 0.1342 - val_accuracy: 0.7616 - val_loss: 1.0976
# Epoch 83/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9491 - loss: 0.1498 - val_accuracy: 0.7643 - val_loss: 1.0067
# Epoch 84/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.9427 - loss: 0.1603 - val_accuracy: 0.7670 - val_loss: 1.0535
# Epoch 85/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 214ms/step - accuracy: 0.9472 - loss: 0.1650 - val_accuracy: 0.7657 - val_loss: 1.0621
# Epoch 86/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 215ms/step - accuracy: 0.9393 - loss: 0.1597 - val_accuracy: 0.7602 - val_loss: 1.0397
# Epoch 87/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 234ms/step - accuracy: 0.9373 - loss: 0.1695 - val_accuracy: 0.7439 - val_loss: 1.2042
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 232ms/step - accuracy: 0.9477 - loss: 0.1586 - val_accuracy: 0.7452 - val_loss: 1.1581
# Epoch 89/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 219ms/step - accuracy: 0.9477 - loss: 0.1473 - val_accuracy: 0.7616 - val_loss: 1.0455
# Epoch 90/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 212ms/step - accuracy: 0.9558 - loss: 0.1383 - val_accuracy: 0.7357 - val_loss: 1.2182
# Epoch 91/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 223ms/step - accuracy: 0.9253 - loss: 0.2059 - val_accuracy: 0.7507 - val_loss: 1.0287
# Epoch 92/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9534 - loss: 0.1364 - val_accuracy: 0.7602 - val_loss: 1.1147
# Epoch 93/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - accuracy: 0.9516 - loss: 0.1457 - val_accuracy: 0.7548 - val_loss: 1.1706
# Epoch 94/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - accuracy: 0.9535 - loss: 0.1476 - val_accuracy: 0.7493 - val_loss: 1.0989
# Epoch 95/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - accuracy: 0.9549 - loss: 0.1275 - val_accuracy: 0.7493 - val_loss: 1.3186
# Epoch 96/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 216ms/step - accuracy: 0.9470 - loss: 0.1646 - val_accuracy: 0.7561 - val_loss: 1.1763
# Epoch 97/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.9494 - loss: 0.1401 - val_accuracy: 0.7589 - val_loss: 1.1356
# Epoch 98/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 227ms/step - accuracy: 0.9477 - loss: 0.1539 - val_accuracy: 0.7520 - val_loss: 1.1230
# Epoch 99/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 232ms/step - accuracy: 0.9553 - loss: 0.1352 - val_accuracy: 0.7643 - val_loss: 1.3302
# Epoch 100/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 26s 281ms/step - accuracy: 0.9515 - loss: 0.1410 - val_accuracy: 0.7493 - val_loss: 1.2603

# %%
# 모델 저장
model.save('./model/flower_classification_model.h5')
print("모델이 'flower_classification_model.h5'로 저장되었습니다.")
# 학습이 오래 걸릴 수 있으므로 파일로 저장하여 필요할 때 로드시키기
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 모델이 'flower_classification_model.h5'로 저장되었습니다.

# %%
# 저장된 모델 불러오기
from tensorflow.keras.models import load_model

model_path = './model/flower_classification_model.h5'  # 저장된 모델 경로
loaded_model = load_model(model_path)
print("저장된 모델이 성공적으로 로드되었습니다.")

# 저장된 모델을 활용한 이미지 예측 함수
def predict_flower_with_loaded_model(img_path, model, class_names):
    """
    이미지 경로와 모델을 입력받아 예측 결과를 출력하고 이미지를 시각화하는 함수.

    Parameters:
        img_path (str): 예측할 이미지 파일 경로.
        model (tf.keras.Model): 저장된 모델.
        class_names (list): 클래스 이름 리스트.
    """
    # 이미지 로드 및 전처리
    img = tf.keras.preprocessing.image.load_img(
        img_path, target_size=(img_height, img_width)
    )
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # 배치 차원 추가

    # 예측 수행
    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    # 예측 결과 출력
    print(
        "이 이미지는 '{}' ({:.2f}% 확률) 입니다."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )

    # 이미지 시각화
    plt.imshow(img)
    plt.axis('off')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 저장된 모델이 성공적으로 로드되었습니다.

# %%
# 테스트 이미지 경로
#test_image_path = './flower_dataset/flower_photos/daisy/5547758_eea9edfd54_n.jpg' # 맞춤
#test_image_path = './flower_dataset/flower_photos/dandelion/7355522_b66e5d3078_m.jpg' # 맞춤
#test_image_path = './flower_dataset/flower_photos/sunflowers/26254755_1bfc494ef1_n.jpg' # 맞춤
#test_image_path = './flower_dataset/flower_photos/tulips/11746367_d23a35b085_n.jpg' # 맞춤
test_image_path = './flower_dataset/flower_photos/roses/12240303_80d87f77a3_n.jpg' # 맟춤
# 예측 실행
predict_flower_with_loaded_model(test_image_path, loaded_model, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 이 이미지는 'roses' (40.45% 확률) 입니다.
