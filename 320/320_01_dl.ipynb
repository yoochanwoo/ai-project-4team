# %% [markdown]
# # 딥러닝

# %% [markdown]
# ## 활성화함수

# %% [markdown]
# ### sigmoid 함수

# %%
import numpy as np
import matplotlib.pylab as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x)) # sigmoid 식 (np.exp(-x) : e^-x)

#그래프 그려보기
x = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(x)
plt.plot(x, y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# ### Tanh 함수

# %%
import numpy as np
import matplotlib.pylab as plt

def tanh(x):
    return np.tanh(x) # 하이퍼볼릭 탄젠트는 넘피 내부에 지원됨

# 그래프 그리기
x = np.arange(-5.0, 5.0, 0.1)
y = tanh(x)
plt.plot(x, y)
plt.ylim(-1.1, 1.1)  # y축 범위 설정
plt.title("Tanh Activation Function")
plt.grid()
plt.show()

# %% [markdown]
# ### ReLU 함수

# %%
import numpy as np
import matplotlib.pylab as plt

def relu(x):
    return np.maximum(0, x) # 0부터 가장 큰 수까지를 리턴

# 그래프 그리기
x = np.arange(-5.0, 5.0, 0.1)
y = relu(x)
plt.plot(x, y)
plt.ylim(-0.5, 5.5)  # y축 범위 설정
plt.title("ReLU Activation Function")
plt.grid()
plt.show()

# %% [markdown]
# ## 텐서플로우(tensorflow)

# %%
### TensorFlow를 활용한 y = 2x + 1 선형회귀 모델 예측 예제 ###
import tensorflow as tf
import numpy as np

# 폰트지정
#plt.rcParams['font.family'] = 'Malgun Gothic'

# 마이너스 부호 깨짐 지정
#plt.rcParams['axes.unicode_minus'] = False

# 숫자가 지수표현식으로 나올 때 지정
#.options.display.float_format = '{:.2f}'.format

# 1. 데이터 준비
# x_data: 입력 데이터, y_data: 실제 값 (정답)
x_data = np.array([0, 1, 2, 3, 4], dtype=np.float32)
y_data = np.array([1, 3, 5, 7, 9], dtype=np.float32)

# 2. 모델 정의
# 가중치(w)와 편향(b)를 변수로 정의
w = tf.Variable(0.0)  # 초기 가중치
b = tf.Variable(0.0)  # 초기 편향

# 예측 함수 (y = wx + b)
def predict(x):
    return w * x + b

# 3. 손실 함수 정의
# 평균 제곱 오차 (Mean Squared Error, MSE) 사용
def loss_fn(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))  # reduce_mean : 제곱한 오차들의 평균

# 4. 최적화 알고리즘 선택
optimizer = tf.optimizers.SGD(learning_rate=0.01)  # 확률적 경사 하강법

# 5. 학습 과정
for step in range(100):  # 100번 반복
    with tf.GradientTape() as tape:
        y_pred = predict(x_data)  # 예측값
        loss = loss_fn(y_data, y_pred)  # 손실 계산

    # 가중치와 편향에 대한 경사도 계산 및 업데이트
    gradients = tape.gradient(loss, [w, b])
    optimizer.apply_gradients(zip(gradients, [w, b]))

    if step % 10 == 0:  # 10번마다 로그 출력
        print(f"Step {step}, Loss: {loss.numpy()}, w: {w.numpy()}, b: {b.numpy()}")
        # 오차가 줄어들고 가중치와 편향치가 점점 자리를 잡아감

# 6. 예측 및 결과 확인
print("Final Parameters:", f"w={w.numpy()}, b={b.numpy()}")
# 최종 가중치와 편향
print("Prediction for x=5:", predict(5).numpy())
# 5에 대한 예측값은 11이 나와야 한다
# x_data = np.array([0, 1, 2, 3, 4], dtype=np.float32)
# y_data = np.array([1, 3, 5, 7, 9], dtype=np.float32)
# Prediction for x=5: 11.110091
# Out:
# Step 0, Loss: 33.0, w: 0.2800000011920929, b: 0.09999999403953552
# Step 10, Loss: 1.8755830526351929, w: 1.6574040651321411, b: 0.6004058718681335
# Step 20, Loss: 0.1229294165968895, w: 1.9802603721618652, b: 0.7298945188522339
# Step 30, Loss: 0.02239181473851204, w: 2.053251266479492, b: 0.7707916498184204
# Step 40, Loss: 0.014991003088653088, w: 2.0671944618225098, b: 0.7900874018669128
# Step 50, Loss: 0.013025244697928429, w: 2.0673303604125977, b: 0.8037028312683105
# Step 60, Loss: 0.011540031060576439, w: 2.06437611579895, b: 0.8154456615447998
# Step 70, Loss: 0.010236968286335468, w: 2.0608623027801514, b: 0.8262498378753662
# Step 80, Loss: 0.009081726893782616, w: 2.0573794841766357, b: 0.8363654017448425
# Step 90, Loss: 0.00805690512061119, w: 2.0540578365325928, b: 0.8458786010742188
# Final Parameters: w=2.051225423812866, b=0.8539638519287109
# Prediction for x=5: 11.110091

# %% [markdown]
# ### keras

# %%
# %pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.1.0
# annotated-types              0.7.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# attrs                        25.2.0
# certifi                      2025.1.31
# charset-normalizer           3.4.1
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.3.1
# cycler                       0.12.1
# dacite                       1.9.2
# debugpy                      1.8.13
# decorator                    5.2.1
# exceptiongroup               1.2.2
# executing                    2.2.0
# flatbuffers                  25.2.10
# fonttools                    4.56.0
# gast                         0.6.0
# google-pasta                 0.2.0
# grpcio                       1.71.0
# h5py                         3.13.0
# htmlmin                      0.1.12
# idna                         3.10
# ImageHash                    4.3.1
# ipykernel                    6.29.5
# ipython                      8.33.0
# jedi                         0.19.2
# Jinja2                       3.1.6
# joblib                       1.4.2
# jupyter_client               8.6.3
# jupyter_core                 5.7.2
# keras                        3.9.0
# kiwisolver                   1.4.8
# libclang                     18.1.1
# llvmlite                     0.44.0
# Markdown                     3.7
# markdown-it-py               3.0.0
# MarkupSafe                   3.0.2
# matplotlib                   3.10.0
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# ml_dtypes                    0.5.1
# multimethod                  1.12
# namex                        0.0.8
# nest-asyncio                 1.6.0
# networkx                     3.4.2
# numba                        0.61.0
# numpy                        2.1.3
# opt_einsum                   3.4.0
# optree                       0.14.1
# packaging                    24.2
# pandas                       2.2.3
# parso                        0.8.4
# patsy                        1.0.1
# phik                         0.12.4
# pillow                       11.1.0
# pip                          25.0.1
# platformdirs                 4.3.6
# prompt_toolkit               3.0.50
# protobuf                     5.29.3
# psutil                       7.0.0
# pure_eval                    0.2.3
# puremagic                    1.28
# pydantic                     2.10.6
# pydantic_core                2.27.2
# Pygments                     2.19.1
# pyparsing                    3.2.1
# python-dateutil              2.9.0.post0
# pytz                         2025.1
# PyWavelets                   1.8.0
# pywin32                      308
# PyYAML                       6.0.2
# pyzmq                        26.2.1
# requests                     2.32.3
# rich                         13.9.4
# scikit-learn                 1.6.1
# scipy                        1.15.2
# seaborn                      0.13.2
# setuptools                   63.2.0
# six                          1.17.0
# stack-data                   0.6.3
# statsmodels                  0.14.4
# tensorboard                  2.19.0
# tensorboard-data-server      0.7.2
# tensorflow                   2.19.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.5.0
# threadpoolctl                3.5.0
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# typeguard                    4.4.2
# typing_extensions            4.12.2
# tzdata                       2025.1
# urllib3                      2.3.0
# visions                      0.8.1
# wcwidth                      0.2.13
# Werkzeug                     3.1.3
# wheel                        0.45.1
# wordcloud                    1.9.4
# wrapt                        1.17.2
# ydata-profiling              4.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show tensorflow
# %pip show keras
# Out:
# Name: tensorflow
# Version: 2.19.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\newtest\myenv\lib\site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# Name: keras
# Version: 3.9.0
# Summary: Multi-backend Keras
# Home-page:
# Author:
# Author-email: Keras team <keras-users@googlegroups.com>
# License: Apache License 2.0
# Location: c:\newtest\myenv\lib\site-packages
# Requires: absl-py, h5py, ml-dtypes, namex, numpy, optree, packaging, rich
# Required-by: tensorflow
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 1. 데이터 준비
# 입력(x)과 출력(y) 데이터를 정의합니다.
x_data = np.array([0, 1, 2, 3, 4], dtype=np.float32)  # 입력 데이터
y_data = np.array([1, 3, 5, 7, 9], dtype=np.float32)  # 정답 데이터

# 2. 모델 정의
# Sequential API를 사용해 신경망을 정의합니다.
model = Sequential([
    Dense(1, input_dim=1)  # 입력 1개, 출력 1개 (선형 회귀)
])

# 3. 모델 컴파일
# 손실 함수와 옵티마이저를 설정합니다.
model.compile(optimizer='sgd', loss='mse')

# 4. 모델 학습
# fit() 메서드로 데이터를 학습시킵니다.
model.fit(x_data, y_data, epochs=50, verbose=1)  # 50번 반복 학습

# 5. 예측 및 평가
# 새로운 데이터로 예측 수행
x_new = np.array([5], dtype=np.float32)
y_new = model.predict(x_new)

print(f"x = 5일 때, 예측된 y = {y_new[0][0]:.2f}")
# Out:
# Epoch 1/50
# c:\NEWTEST\myenv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 88.6309
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 66.4678
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 49.8476
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 37.3840
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 28.0376
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 21.0286
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 15.7725
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 11.8309
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 8.8751
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.6584
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.9961
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.7496
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.8147
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.1136
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.5878
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.1935
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.8978
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.6760
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.5096
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3848
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2912
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2210
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1683
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1288
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0991
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0768
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0600
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0474
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0380
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0308
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0255
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0214
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0183
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0160
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0142
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0129
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0118
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0110
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0104
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0099
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0095
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0092
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0089
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0087
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0085
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0083
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0082
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0080
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0079
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# x = 5일 때, 예측된 y = 10.87

# %% [markdown]
# ### MINIST예제 (CNN모델)

# %%
# 1. 필요한 라이브러리 임포트
import tensorflow as tf  # 딥러닝 라이브러리
from tensorflow.keras import layers, models  # 신경망 계층 및 모델 설계
from tensorflow.keras.datasets import mnist  # MNIST 데이터셋
import matplotlib.pyplot as plt  # 시각화 도구

# 2. 데이터 로드 및 전처리
# MNIST 데이터셋은 이미 나뉘어 제공 (학습/테스트 데이터)
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# MNIST 이미지는 28x28 크기, 채널 정보 추가 (흑백 이미지는 채널 1개, 컬러는 3개)
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1)).astype('float32') / 255.0  # 0~1로 정규화, 픽셀은 0에서 255까지 값을 가짐
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)).astype('float32') / 255.0

# 레이블을 One-Hot Encoding (숫자 0~9를 벡터로 변환)
# One-Hot Encoding : 범주형 데이터를 수치형 데이터로 변환하는 방법
if len(y_train.shape) == 1:  # shape이 (n,)인지 확인
    y_train = tf.keras.utils.to_categorical(y_train, 10)  # to_categorical(원핫인코딩 대상, 클래스 갯수)
if len(y_test.shape) == 1:  # shape이 (n,)인지 확인
    y_test = tf.keras.utils.to_categorical(y_test, 10)

# 3. CNN 모델 정의
model = models.Sequential()  # 순차적 모델 선언

# 첫 번째 합성곱 계층: 필터 크기 3x3, 필터 수 32, 활성화 함수 ReLU
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))

"""
activation 으로 위에 있는 활성함수들을 학습에 적용할 수 있음

1. 시그모이드(Sigmoid) : 이진분류, 확률계산
    - 값을 0과 1 사이의 확률값으로 변환시킴
    - 입력값이 너무 크면 가중치를 잘 잡지 못함
    - 분류 모델이나 로지스틱 회귀에 사용
2. 하이퍼볼릭 탄젠트(tanh) : 중심이 0인 데이터
    - 값을 -1과 1 사이의 값으로 정규화함
    - 시그모이드와 비슷하지만 비교적 중간 영역의 기울기가 가파름(가중치 적용이 비교적 큼)
3. ReLU : 이미지 분류
    - 음수는 0, 양수는 선형적(그대로)으로 변환
    - 계산의 단순성 덕분에 학습속도가 빠름
    - 우상향으로 발산하므로 기울기 소실문제가 있음
    - 음수영역에서는 0으로만 변환되는 문제점이 있음
4. 소프트맥스(Softmax) : 다중 클래스 분류
    - 시그모이드와 비슷하게 0과 1사이의 값으로 변환시키지만,
        각 출력값들의 합이 1이 되도록 정규화됨(확률분포)
    - 확률을 출력할 때 용이
    - 분류문제에 자주 사용
"""
"""
CNN 모델 정의
1. Con2D : 필터링
    - 필터를 적용하여 입력데이터의 특징을 추출
2. MaxPooling2D : 압축
    - 공간적 크기를 줄여 계산량 감소 및 특징 강화
3. Flatten : 전달
    - 2차원 데이터를 1차원 벡터로 변환하여 Dense 계층에 연결
4. Dense : 판단
    - Fully Connected Layer로 분류 결과를 도출
    
1번과 2번과정을 서너번 반복하고
마지막 Convolution(1번)을 거쳐
3번과정, 4번과정을 차례대로 진행
"""

# 풀링 계층: 2x2 크기로 다운샘플링
model.add(layers.MaxPooling2D((2, 2)))

# 두 번째 합성곱 계층: 필터 수 64
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# 세 번째 합성곱 계층: 필터 수 64
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Fully Connected Layer를 연결하기 위해 Flatten 처리
model.add(layers.Flatten())

# Fully Connected Layer 1: 뉴런 수 64, 활성화 함수 ReLU
model.add(layers.Dense(64, activation='relu'))

# 출력층: 뉴런 수 10(클래스 수), 활성화 함수 Softmax
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 30s 3us/step
# c:\NEWTEST\myenv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# 4. 모델 컴파일
model.compile(optimizer='adam',               # 최적화 알고리즘 (손실값을 최소화하면서 모델이 최적의 가중치를 찾도록 안내하는 역할)
              loss='categorical_crossentropy', # 다중 클래스 분류 손실 함수
              metrics=['accuracy'])           # 평가 지표: 정확도

# 5. 모델 학습
history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)

# 6. 모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"테스트 정확도: {test_acc:.4f}")
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.8425 - loss: 0.5163 - val_accuracy: 0.9771 - val_loss: 0.0799
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9799 - loss: 0.0629 - val_accuracy: 0.9841 - val_loss: 0.0513
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9866 - loss: 0.0429 - val_accuracy: 0.9856 - val_loss: 0.0496
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9897 - loss: 0.0319 - val_accuracy: 0.9877 - val_loss: 0.0414
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9912 - loss: 0.0259 - val_accuracy: 0.9879 - val_loss: 0.0450
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9867 - loss: 0.0441
# 테스트 정확도: 0.9892

# %%
# 7. 결과 확인: 테스트 데이터에서 임의의 이미지 예측
import numpy as np

# 테스트 데이터에서 첫 번째 샘플을 가져옴
sample_image = x_test[0]   # 첫번 째 이미지 저장
sample_label = np.argmax(y_test[0])   # y_test[0] 배열에서 가장 큰 값을 가지는 요소의 인덱스를 찾아 sample_label 변수에 저장

# 모델로 예측 수행
predicted_label = np.argmax(model.predict(sample_image.reshape(1, 28, 28, 1)))

# 결과 출력
plt.imshow(sample_image.reshape(28, 28), cmap='gray')
plt.title(f"real value: {sample_label}, forcast value: {predicted_label}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
